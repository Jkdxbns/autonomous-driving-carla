# %% [markdown]
# YOLO11 Model Training Script
# ===========================
# Train YOLO11n model on CARLA-generated dataset (single-map specialization).
#
# Usage examples:
#
#     # Full-model fine-tuning (recommended for single CARLA map)
#     python train_yolo.py \
#         --dataset yolo_carla_dataset \
#         --model yolo11n.pt \
#         --epochs 250 \
#         --batch 16 \
#         --augment \
#         --pretrained
#
#     # Experiment: freeze first 10 layers (more generic backbone)
#     python train_yolo.py \
#         --dataset yolo_carla_dataset \
#         --model yolo11n.pt \
#         --epochs 120 \
#         --batch 16 \
#         --augment \
#         --pretrained \
#         --freeze 10

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.6 MB/s eta 0:00:00

# %%
import os
import shutil
import argparse

from pathlib import Path
from types import SimpleNamespace

import torch
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
def check_gpu():
    """Check GPU availability"""
    if torch.cuda.is_available():
        print(f"✓ GPU available: {torch.cuda.get_device_name(0)}")
        print(f"  CUDA version: {torch.version.cuda}")
        print(f"  GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
        return True
    else:
        print("⚠ No GPU available. Training will use CPU (slower)")
        return False

# %%
def train_model(args):
    """Train YOLO model"""
    print("\n=== YOLO Training Configuration ===")
    print(f"Dataset dir : {args.dataset}")
    print(f"Model       : {args.model}")
    print(f"Epochs      : {args.epochs}")
    print(f"Batch size  : {args.batch}")
    print(f"Image size  : {args.imgsz}")
    print(f"Workers     : {args.workers}")
    print(f"Optimizer   : {args.optimizer}")
    print(f"LR0         : {args.lr0}")
    print(f"Patience    : {args.patience}")
    print(f"Freeze      : {args.freeze}  (0 = train full model)")
    print(f"Project     : {args.project}")
    print(f"Run name    : {args.name}")
    print(f"Pretrained  : {args.pretrained}")
    print(f"Augment     : {args.augment}")
    print(f"Cache       : {args.cache}")
    print(f"Resume      : {args.resume}")
    print(f"Validate    : {args.validate}")

    # Check dataset.yaml exists
    yaml_path = os.path.join(args.dataset, "dataset.yaml")
    if not os.path.exists(yaml_path):
        print(f"\n✗ Error: dataset.yaml not found at {yaml_path}")
        return

    # Load model
    print(f"\nLoading model: {args.model}")
    model = YOLO(args.model)

    # Check GPU
    has_gpu = check_gpu()
    device = 0 if has_gpu and not args.cpu else "cpu"
    print(f"\nUsing device: {device}")

    # Start training
    print("\n=== Starting Training ===\n")

    results = model.train(
        data=yaml_path,
        epochs=args.epochs,
        imgsz=args.imgsz,
        batch=args.batch,
        workers=args.workers,
        device=device,
        project=args.project,
        name=args.name,
        pretrained=args.pretrained,
        optimizer=args.optimizer,
        lr0=args.lr0,
        patience=args.patience,
        save=True,
        save_period=args.save_period,
        cache=args.cache,
        augment=args.augment,
        resume=args.resume,
        verbose=True,
        freeze=args.freeze,   # <-- NEW: control how much of the backbone is frozen
    )

    print("\n=== Training Complete ===")
    print(f"Results saved to: {results.save_dir}")

    # ---- NEW: save final model somewhere explicit ----
    best_weights = Path(results.save_dir) / "weights" / "best.pt"
    last_weights = Path(results.save_dir) / "weights" / "last.pt"

    print(f"Best weights: {best_weights}")
    print(f"Last weights: {last_weights}")

    if args.final_model_path:
        final_path = Path(args.final_model_path)
        final_path.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy2(best_weights, final_path)
        print(f"✔ Copied best weights to: {final_path}")

    # Optional validation
    if args.validate:
        print("\n=== Running Validation ===")
        metrics = model.val()
        print("\nValidation Results:")
        print(f"  mAP50    : {metrics.box.map50:.4f}")
        print(f"  mAP50-95 : {metrics.box.map:.4f}")
        print(f"  Precision: {metrics.box.mp:.4f}")
        print(f"  Recall   : {metrics.box.mr:.4f}")

    return results

# %%
def main():
    parser = argparse.ArgumentParser(description="Train YOLO11 model on CARLA dataset")

    # Dataset
    parser.add_argument(
        "--dataset",
        type=str,
        required=True,
        help="Path to dataset directory containing dataset.yaml",
    )

    # Model
    parser.add_argument(
        "--model",
        type=str,
        default="yolo11n.pt",
        help="Model to use (yolo11n/s/m/l/x.pt)",
    )

    # Training parameters
    parser.add_argument(
        "--epochs",
        type=int,
        default=250,  # higher by default – okay to overfit to single map
        help="Number of training epochs",
    )
    parser.add_argument(
        "--batch",
        type=int,
        default=16,
        help="Batch size (-1 for auto)",
    )
    parser.add_argument(
        "--imgsz",
        type=int,
        default=640,
        help="Image size for training",
    )
    parser.add_argument(
        "--workers",
        type=int,
        default=8,
        help="Number of dataloader workers",
    )

    # Optimization
    parser.add_argument(
        "--optimizer",
        type=str,
        default="AdamW",
        choices=["SGD", "Adam", "AdamW", "auto"],
        help="Optimizer",
    )
    parser.add_argument(
        "--lr0",
        type=float,
        default=0.005,
        help="Initial learning rate",
    )
    parser.add_argument(
        "--patience",
        type=int,
        default=60,
        help="Epochs to wait for no improvement for early stopping",
    )

    # Save options
    parser.add_argument(
        "--project",
        type=str,
        default="runs/train",
        help="Project directory",
    )
    parser.add_argument(
        "--name",
        type=str,
        default="carla_yolo11n_one_map",
        help="Experiment name",
    )
    parser.add_argument(
        "--save-period",
        type=int,
        default=-1,
        help="Save checkpoint every x epochs (-1 for disabled)",
    )

    # Advanced / behavior options
    parser.add_argument(
        "--pretrained",
        action="store_true",
        help="Use pretrained weights (recommended)",
    )
    parser.add_argument(
        "--cache",
        action="store_true",
        help="Cache images for faster training",
    )
    parser.add_argument(
        "--augment",
        action="store_true",
        help="Apply data augmentation",
    )
    parser.add_argument(
        "--cpu",
        action="store_true",
        help="Force CPU usage",
    )
    parser.add_argument(
        "--resume",
        action="store_true",
        help="Resume training from last checkpoint",
    )
    parser.add_argument(
        "--validate",
        action="store_true",
        help="Run validation after training",
    )

    # NEW: freeze control
    parser.add_argument(
        "--freeze",
        type=int,
        default=0,
        help="Number of backbone layers to freeze (0 = train full model)",
    )

    parser.add_argument(
        "--final-model-path",
        type=str,
        default="",
        help="Optional path to copy best.pt after training (e.g. inside Drive)",
    )

    args = parser.parse_args()

    # Train
    train_model(args)

# %%
# from train_yolo import train_model  # <-- delete this line

dataset_root = "/content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset"

args = SimpleNamespace(
    dataset=dataset_root,
    model="yolo11n.pt",
    epochs=250,
    batch=128,
    imgsz=640,
    workers=8,
    optimizer="AdamW",
    lr0=0.005,
    patience=60,
    project="/content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs",
    name="carla_yolo11n_one_map",
    save_period=-1,
    pretrained=True,
    cache=True,
    augment=True,
    cpu=False,
    resume=False,
    validate=True,
    freeze=0,
    final_model_path="/content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/yolo11n_merged.pt",
)

results = train_model(args)
# Out:
# === YOLO Training Configuration ===
# Dataset dir : /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset
# Model       : yolo11n.pt
# Epochs      : 250
# Batch size  : 128
# Image size  : 640
# Workers     : 8
# Optimizer   : AdamW
# LR0         : 0.005
# Patience    : 60
# Freeze      : 0  (0 = train full model)
# Project     : /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs
# Run name    : carla_yolo11n_one_map
# Pretrained  : True
# Augment     : True
# Cache       : True
# Resume      : False
# Validate    : True
#
# Loading model: yolo11n.pt
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 268.9MB/s 0.0s
# ✓ GPU available: NVIDIA L4
#   CUDA version: 12.6
#   GPU memory: 23.80 GB
#
# Using device: 0
#
# === Starting Training ===
#
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=250, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=0, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=carla_yolo11n_one_map2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=60, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 42.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 0.5±0.1 MB/s, size: 311.5 KB)
# train: Scanning /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/train/labels.cache... 2812 images, 351 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2812/2812 3.8Mit/s 0.0s
# train: /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/train/images/001418.jpg: 1 duplicate labels removed
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (1.8GB RAM): 100% ━━━━━━━━━━━━ 2812/2812 13.4it/s 3:29
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.6±0.1 ms, read: 0.3±0.1 MB/s, size: 287.3 KB)
# val: Scanning /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/val/labels.cache... 790 images, 91 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 790/790 1.0Mit/s 0.0s
# val: /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/val/images/000061.jpg: 1 duplicate labels removed
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.5GB RAM): 100% ━━━━━━━━━━━━ 790/790 12.0it/s 1:06
# Plotting labels to /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/labels.jpg...
# optimizer: AdamW(lr=0.005, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.001), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2
# Starting training for 250 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/250      16.3G       1.69      3.602      1.086        431        640: 100% ━━━━━━━━━━━━ 22/22 1.7s/it 37.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.3s
#                    all        790       1626    0.00247     0.0152      0.002   0.000822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/250      16.4G      1.451      1.257      1.042        403        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.7s
#                    all        790       1626    0.00641    0.00624    0.00329    0.00145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/250      16.4G      1.362      1.019      1.031        427        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.4s
#                    all        790       1626      0.251     0.0351      0.127     0.0426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/250      16.5G      1.359      0.966      1.025        424        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626     0.0884       0.52      0.152     0.0697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/250      16.4G      1.338     0.9281      1.017        382        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.257      0.232       0.16     0.0658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/250      16.4G      1.308     0.8637      1.009        393        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.7s
#                    all        790       1626      0.344      0.547      0.295      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/250      16.4G      1.248      0.832     0.9908        424        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.484       0.53      0.368      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/250      16.4G      1.216     0.8039     0.9823        427        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.496      0.576      0.404      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/250      16.4G      1.178     0.7842     0.9718        407        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.545      0.576      0.478      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/250      16.4G      1.161     0.7537     0.9676        434        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.688       0.48      0.521      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/250      16.4G      1.139     0.7281     0.9637        424        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.789      0.684      0.753      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/250      16.4G      1.123     0.7186     0.9425        396        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.835      0.679       0.75      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/250      16.4G      1.091     0.7005     0.9509        394        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.681      0.675      0.701      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/250      16.4G      1.059     0.6646     0.9271        433        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.7s
#                    all        790       1626      0.708      0.729      0.727      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/250      16.4G      1.065     0.6605     0.9275        406        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.687      0.721      0.672      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/250      16.5G      1.041      0.651     0.9276        412        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.779      0.635       0.68      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/250      16.4G      1.049     0.6559     0.9253        470        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.864      0.662      0.768      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/250      16.4G      1.033     0.6451     0.9239        394        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.803       0.73      0.791      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/250      16.3G      1.002     0.6219     0.9199        459        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.872      0.778      0.853      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/250      16.4G     0.9987     0.6284     0.9146        456        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626       0.92      0.804      0.885      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/250      16.4G      1.002     0.6304     0.9184        407        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.771       0.66      0.722       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/250      16.4G     0.9903     0.6153      0.916        491        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.895      0.754      0.859      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/250      16.5G     0.9741     0.6074     0.9038        453        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.863      0.776      0.832       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/250      16.4G     0.9457     0.5901     0.9045        436        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0
0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     232/250      16.5G     0.5127     0.3101     0.8108        436        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.929      0.871      0.926      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     233/250      16.4G     0.5174     0.3098     0.8092        495        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.928       0.88      0.926      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     234/250      16.4G     0.5148     0.3098     0.8059        423        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.938      0.878      0.926      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     235/250      16.4G     0.5126     0.3134     0.8045        420        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.935      0.875      0.926      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     236/250      16.4G     0.5161     0.3076     0.8103        452        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.928       0.88      0.926      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     237/250      16.4G     0.5008     0.3008     0.8045        430        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.932      0.882      0.927      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     238/250      16.4G     0.5134     0.3064     0.8085        452        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.934      0.882      0.928      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     239/250      16.4G     0.5165     0.3127     0.8102        404        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.927      0.884      0.926      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     240/250      16.3G     0.5087      0.308     0.8083        413        640: 100% ━━━━━━━━━━━━ 22/22 1.2it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.929      0.883      0.926       0.72
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     241/250      16.2G     0.5449     0.3239     0.8032        255        640: 100% ━━━━━━━━━━━━ 22/22 1.1it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.6s
#                    all        790       1626      0.937      0.873      0.925      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     242/250      16.2G     0.5228     0.3054     0.8046        221        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.938      0.867      0.924      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     243/250      16.2G     0.5099     0.3028     0.8003        222        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.932      0.866      0.924      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     244/250      16.2G     0.5033     0.2964     0.7941        231        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.944      0.856      0.923      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     245/250      16.2G      0.504     0.2998     0.7967        238        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.931      0.866      0.924      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     246/250      16.2G     0.5083     0.2997     0.8016        264        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626       0.93      0.865      0.921      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     247/250      16.2G     0.4956     0.2934      0.801        225        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.925      0.876      0.923      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     248/250      16.2G     0.4909     0.2912        0.8        229        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        790       1626      0.925      0.879      0.924      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     249/250      16.2G     0.4992     0.2923     0.7986        224        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.922      0.877      0.924      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     250/250      16.2G     0.4887     0.2953     0.7938        221        640: 100% ━━━━━━━━━━━━ 22/22 1.3it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        790       1626      0.922       0.88      0.924      0.715
#
# 250 epochs completed in 1.455 hours.
# Optimizer stripped from /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/weights/best.pt, 5.5MB
#
# Validating /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.3s/it 17.3s
#                    all        790       1626      0.905      0.876      0.916       0.67
#                vehicle        344        561      0.894      0.902      0.911      0.803
#             pedestrian        380        712      0.836      0.867      0.896      0.608
#          traffic_light        283        283      0.934      0.851      0.906      0.595
#            speed_limit         70         70      0.954      0.882      0.952      0.674
# Speed: 0.1ms preprocess, 18.3ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2
#
# === Training Complete ===
# Results saved to: /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2
# Best weights: /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/weights/best.pt
# Last weights: /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/carla_yolo11n_one_map2/weights/last.pt
# ✔ Copied best weights to: /content/drive/MyDrive/datasets/cmpe789/cmpe789_yolo_runs/yolo11n_merged.pt
#
# === Running Validation ===
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 136.1±30.6 MB/s, size: 301.8 KB)
# val: Scanning /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/val/labels.cache... 790 images, 91 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 790/790 1.2Mit/s 0.0s
# val: /content/drive/MyDrive/datasets/cmpe789/yolo_carla_dataset/val/images/000061.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 6.7it/s 7.4s
#                    all        790       1626      0.935      0.882      0.928      0.728
#                vehicle        344        561      0.902      0.907      0.916      0.848
#             pedestrian        380        712      0.865      0.856      0.901      0.642
#          traffic_light        283        283      0.972      0.841      0.932      0.665
#            speed_limit         70         70          1      0.925      0.962      0.757
# Speed: 0.5ms preprocess, 1.1ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/val
#
# Validation Results:
#   mAP50    : 0.9277
#   mAP50-95 : 0.7278
#   Precision: 0.9349
#   Recall   : 0.8823
